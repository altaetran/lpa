# %%
# Requires the following packages: seaborn, pandas, pandas_datareader, matplotlib
import lpa
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, '../datasets/finance/')
from finance_dataset import get_dataset
sys.path.insert(0, '../datasets/')
import plot_tools as pt
reload(pt)
# Out:
# <module 'plot_tools' from '../datasets/plot_tools.pyc'>

# %%
T_train,X_train,T_val,X_val,T_test,X_test,stock_info = get_dataset()
# Out:
# Number of companies: 2610
# ../datasets/finance/finance_dataset.py:87: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   for i in range(X.shape[0])])
# Extracted 2125 companies for analysis
# Extracted 2102 companies for further analysis

# %%
# Lets plot the data over time
m = X_train.shape[0]
idx_to_plot = range(1,m,20)

sort_idx = np.argsort(X_train[idx_to_plot,200], axis=0)

ax = pt.plot_series(T_train, X_train[idx_to_plot,:], linewidth=1, sort_idx=sort_idx)
ax = pt.plot_series(T_val, X_val[idx_to_plot,:], linewidth=1, sort_idx=sort_idx, ax=ax, theme='purple')
ax = pt.plot_series(T_test, X_test[idx_to_plot,:], linewidth=1, sort_idx=sort_idx, ax=ax, theme='red')

plt.xlim(T_train[0],T_test[-1])
plt.show()

# %%
# Let's fit a standard vector autoregressive model
n_lags = 4
va = lpa.VAR(n_lags)
va.fit(X_train)
train_err = va.one_step_rmse(X_train)
val_err = va.one_step_rmse(X_val)

print('Training error: '+"{0:05f}".format(train_err))
print('Validation error: '+"{0:05f}".format(val_err))
# Out:
# Training error: 0.000000
# Validation error: 9.485151

# %%
n_components = 100
n_lags = 1
lp = lpa.LPA(n_components,n_lags,verbose=True,basis='unstructured',approximate=False,n_seed=10)
X_lat = lp.fit_predict_latent(X_train)
train_err = lp.one_step_rmse(X_train)
val_err = lp.one_step_rmse(X_val)

print('Training error: '+"{0:05f}".format(train_err))
print('Validation error: '+"{0:05f}".format(val_err))
# Out:
# >>Extracting data from time series
# >>Identifying latent processes
# >> Beginning seed: 0
# Iteration:      0 | loss: 168.339
# Iteration:     73 | loss: 5.915
# >> Beginning seed: 1
# Iteration:      0 | loss: 169.203
# Iteration:     83 | loss: 5.715
# >> Beginning seed: 2
# Iteration:      0 | loss: 169.124
# Iteration:     43 | loss: 7.122
# >> Beginning seed: 3
# Iteration:      0 | loss: 168.849
# Iteration:     73 | loss: 6.07
# >> Beginning seed: 4
# Iteration:      0 | loss: 168.9
# Iteration:    100 | loss: 6.982
# Iteration:    129 | loss: 6.746
# >> Beginning seed: 5
# Iteration:      0 | loss: 167.84
# Iteration:     44 | loss: 6.602
# >> Beginning seed: 6
# Iteration:      0 | loss: 168.658
# Iteration:    100 | loss: 5.547
# Iteration:    104 | loss: 5.542
# >> Beginning seed: 7
# Iteration:      0 | loss: 169.505
# Iteration:     41 | loss: 5.727
# >> Beginning seed: 8
# Iteration:      0 | loss: 168.96
# Iteration:    100 | loss: 6.671
# Iteration:    113 | loss: 6.027
# >> Beginning seed: 9
# Iteration:      0 | loss: 167.986
# Iteration:     53 | loss: 7.232
# >>Leaving basis unstructured
# Training error: 2.354091
# Validation error: 8.265326

# %%
test_err = lp.one_step_rmse(X_test)
print('Test error: '+"{0:05f}".format(test_err))
# Out:
# Test error: 13.653996

# %%
# The training error looks good. Let's optimize hyperparameters for the autoregressive model and see its performance
best_va = None
best_err = 1e64
best_params = None

for n_lags in [1,2,3,4,5]:
    va = lpa.VAR(n_lags,verbose=False)
    va.fit(X_train)
    val_err = va.one_step_rmse(X_val)
    if val_err < best_err:
        best_params = n_lags
        best_va = va
        best_err = val_err
    print val_err
print best_err

# Get the test error of the best one
test_err = best_va.one_step_rmse(X_test)
print('Test error: '+"{0:05f}".format(test_err))
# Out:
# 12.8895970023
# 10.3676293314
# 9.76310048944
# 9.48510694947
# 9.35542783451
# 9.35542783451
# Test error: 15.988372

# %%
best_lp = None
best_err = 1e64
best_params = None

for n_lags in [1,2,3,4,5]:
    for n_components in [1,10,50,100,200,300,400,500]:
        print (n_components, n_lags)
        lp = lpa.LPA(n_components,n_lags,verbose=False,basis='unstructured',n_seed=10)
        lp.fit(X_train)
        val_err = lp.one_step_rmse(X_val)
        print(val_err)
        if val_err < best_err:
            best_params = (n_components,n_lags)
            best_lp = lp
            best_err = val_err
# Out:
# (1, 1)
# 14.6953454196
# (10, 1)
# 10.2736247986
# (50, 1)
# 8.50909934004
# (100, 1)
# 8.24099809794
# (200, 1)
# 8.19201051359
# (300, 1)
# 8.82318814048
# (400, 1)
# 9.21406696989
# (500, 1)
# 10.2193370658
# (1, 2)
# 14.6993148464
# (10, 2)
# 10.2665412161
# (50, 2)
# 8.52722779392
# (100, 2)
# 8.3764845593
# (200, 2)
# 8.58522966703
# (300, 2)
# 10.8447200848
# (400, 2)
# 24.2400175544
# (500, 2)
# 17.8573579461
# (1, 3)
# 14.7001732602
# (10, 3)
# 10.3174970302
# (50, 3)
# 8.53877699735
# (100, 3)
# 8.29162622618
# (200, 3)
# 10.3195430848
# (300, 3)
# 49.8720303295
# (400, 3)
# 11.4440990773
# (500, 3)
# 10.9453314523
# (1, 4)
# 14.700316808
# (10, 4)
# 10.3613675714
# (50, 4)
# 8.5903463874
# (100, 4)
# 8.4797371635
# (200, 4)
# 15.6104871421
# (300, 4)
# 11.1870478716
# (400, 4)
# 10.2956748374
# (500, 4)
# 9.88465423931
# (1, 5)
# 14.7003838996
# (10, 5)
# 10.420939032
# (50, 5)
# 8.70923794896
# (100, 5)
# 8.65146458004
# (200, 5)
# 15.7699600264
# (300, 5)
# 10.7451559477
# (400, 5)
# 9.70391051843
# (500, 5)
# 9.71229129328

# %%
# Get the test error of the best one
test_err = best_lp.one_step_rmse(X_test)
print('Test error: '+"{0:05f}".format(test_err))

# %%
val_errs = np.array([
                    [14.6953454196,10.2736247986,8.50909934004,8.265326,8.389994,8.82318814048,9.21406696989,10.2193370658],
                    [14.6993148464,10.2665412161,8.52722779392,8.3764845593,8.58522966703,10.8447200848,24.2400175544,17.8573579461],
                    [14.7001732602,10.3174970302,8.53877699735,8.29162622618,10.3195430848,49.8720303295,11.4440990773,10.9453314523],
                    [14.700316808,10.3613675714,8.5903463874,8.4797371635,15.6104871421,11.1870478716,10.2956748374,9.88465423931],
                    [14.7003838996,10.420939032,8.70923794896,8.65146458004,15.7699600264,10.7451559477,9.70391051843,9.71229129328]])
# Out:
# 1.6663001440900269

# %%
test = np.arange(10)
test[-2]
# Out:
# 8

# %%
T_pred, X_pred, X_lat_pred = va.predict_traj(T_train,X_train,T_val[-1])

residuals = X_pred[:,1:]-X_val
pt.plot_series(T_val,residuals)
plt.xlim([T_val[0]-1,T_val[5]])
plt.show()

# %%
T_pred, X_pred, X_lat_pred = lp.predict_traj(T_train,X_train,T_val[-1])

residuals = X_pred[:,1:]-X_val
pt.plot_series(T_val,residuals)
plt.xlim([T_val[0]-1,T_val[5]])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-4e2eee74b0fd> in <module>()
# ----> 1 T_pred, X_pred, X_lat_pred = lp.predict_traj(T_train,X_train,T_val[-1])
#       2
#       3 residuals = X_pred[:,1:]-X_val
#       4 pt.plot_series(T_val,residuals)
#       5 plt.xlim([T_val[0]-1,T_val[5]])
#
# /usr/local/lib/python2.7/site-packages/lpa/models.pyc in predict_traj(self, times, X, T, dt)
#     387         init_times, X_init = extract_initial(times,X,self._r)
#     388         T_start = times[-1]
# --> 389         times, X_pred, X_lat_pred = _predict_traj(self._W, self._A, self._b, self._r, X_init,T,T_start,dt)
#     390
#     391         X_pred += self._means[:,np.newaxis]
#
# AttributeError: 'LPA' object has no attribute '_W'

# %%
# Let's fit a standard vector autoregressive model
n_lags = 4
va = lpa.VAR(n_lags,forward_backward=True)
va.fit(X_train)
train_err = va.one_step_rmse(X_train)
val_err = va.one_step_rmse(X_val)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-96873ca9c3c6> in <module>()
#       2 n_lags = 4
#       3 va = lpa.VAR(n_lags,forward_backward=True)
# ----> 4 va.fit(X_train)
#       5 train_err = va.one_step_rmse(X_train)
#       6 val_err = va.one_step_rmse(X_val)
#
# /usr/local/lib/python2.7/site-packages/lpa/models.pyc in fit(self, X)
#      57         W = np.eye(m)  # Can solve for A,b assuming latent process autoregression with W=I
#      58
# ---> 59         A, b = get_A_b(W,Xr,Xp)
#      60
#      61         self._W = W
#
# /usr/local/lib/python2.7/site-packages/lpa/lpa_functions.pyc in get_A_b(W, Mr, Mp, lam)
#     283     # Get autocovariance
#     284     Gamma_var = I_m_Pi(Z_ast_var,Z_ast_var,n) + np.eye(r*p)*(lam+1e-6)
# --> 285     V_var = I_m_Pi(Y_var,Z_ast_var,n)
#     286
#     287     # Invert to get true values
#
# /usr/local/lib/python2.7/site-packages/lpa/auxilary_functions.pyc in I_m_Pi(A, B, m)
#      56
#      57     # Get eye term
# ---> 58     eye_term = A.dot(B.T)
#      59
#      60     # Get proj term
#
# ValueError: shapes (2102,1806) and (1805,8408) not aligned: 1806 (dim 1) != 1805 (dim 0)
